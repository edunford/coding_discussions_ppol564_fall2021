# %%
# Import modules
import numpy as np
import pandas as pd
import requests

# %%
# Read Al Jazeera article as a string
with open("aljazeera-khashoggi.txt") as aljazeera_text:
    aj = aljazeera_text.read()

# %%
# Read BBC article as a string
with open("bbc-khashoggi.txt") as bbc_text:
    bbc = bbc_text.read()

# %%
# Read Breitbart article as a string
with open("breitbart-khashoggi.txt") as breitbart_text:
    bb = breitbart_text.read()

# %%
# Read CNN article as a string
with open("cnn-khashoggi.txt") as cnn_text:
    cnn = cnn_text.read()

# %%
# Read Fox article as a string
with open("fox-khashoggi.txt") as fox_text:
    fox = fox_text.read()

# %%
# Open stop_words
stop_words = pd.read_csv("stop_words.csv")

# %%
def tokenize(text=None):
    '''
    This is a function used to split strings that were formatted in sentences into a list of individual words
    '''
    text = text.lower()
    text = text.replace('-','')
    text = text.replace('(','')
    text = text.replace(')','')
    text = text.replace('"','')
    text = text.replace(',','')
    text = text.replace('[','')
    text = text.replace(']','')
    text = text.replace('?','')
    text = text.replace('.','')
    text_list = text.split()
    return text_list
# Out:
# ['saudi',
#  'officials',
#  'planned',
#  'the',
#  'savage',
#  'murder',
#  'of',
#  'saudi',
#  'writer',
#  'jamal',
#  'khashoggi',
#  'days',
#  'before',
#  'his',
#  'death',
#  'turkish',
#  'president',
#  'recep',
#  'tayyip',
#  'erdogan',
#  'said',
#  'tuesday',
#  'erdogan',
#  'revealed',
#  'the',
#  'details',
#  'of',
#  'the',
#  'country’s',
#  'investigation',
#  'into',
#  'khashoggi’s',
#  'killing',
#  'after',
#  'he',
#  'walked',
#  'into',
#  'the',
#  'saudi',
#  'consulate',
#  'in',
#  'istanbul',
#  'on',
#  'oct',
#  '2',
#  'contradicting',
#  'saudi',
#  'arabia’s',
#  'explanation',
#  'that',
#  'the',
#  'writer',
#  'was',
#  'killed',
#  'in',
#  'a',
#  '“fistfight”',
#  'erdogan',
#  'fell',
#  'short',
#  'of',
#  'blaming',
#  'saudi',
#  'crown',
#  'prince',
#  'mohammed',
#  'bin',
#  'salman',
#  'and',
#  'made',
#  'no',
#  'mention',
#  'of',
#  'whether',
#  'a',
#  'tape',
#  'exists',
#  'of',
#  "khashoggi's",
#  'killing',
#  'however',
#  'he',
#  'kept',
#  'the',
#  'pressure',
#  'on',
#  'the',
#  'kingdom',
#  'with',
#  'his',
#  'demands',
#  'for',
#  'punishment',
#  'of',
#  'all',
#  'the',
#  'people',
#  'involved',
#  'in',
#  'the',
#  'murder',
#  '“all',
#  'evidence',
#  'gathered',
#  'shows',
#  'that',
#  'jamal',
#  'khashoggi',
#  'was',
#  'the',
#  'victim',
#  'of',
#  'a',
#  'savage',
#  'murder',
#  'to',
#  'cover',
#  'up',
#  'such',
#  'a',
#  'savagery',
#  'would',
#  'hurt',
#  'the',
#  'human',
#  'conscience”',
#  'he',
#  'said',
#  'erdogan',
#  'said',
#  'he',
#  'wanted',
#  'saudi',
#  'arabia',
#  'to',
#  'allow',
#  'the',
#  '18',
#  'suspects',
#  'detained',
#  'in',
#  'the',
#  'columnist’s',
#  'killing',
#  'to',
#  'be',
#  'tried',
#  'in',
#  'turkish',
#  'courts',
#  '“to',
#  'blame',
#  'such',
#  'an',
#  'incident',
#  'on',
#  'a',
#  'handful',
#  'of',
#  'security',
#  'and',
#  'intelligence',
#  'members',
#  'would',
#  'not',
#  'satisfy',
#  'us',
#  'or',
#  'the',
#  'international',
#  'community”',
#  'erdogan',
#  'said',
#  '“saudi',
#  'arabia',
#  'has',
#  'taken',
#  'an',
#  'important',
#  'step',
#  'by',
#  'admitting',
#  'the',
#  'murder',
#  'as',
#  'of',
#  'now',
#  'we',
#  'expect',
#  'of',
#  'them',
#  'to',
#  'openly',
#  'bring',
#  'to',
#  'light',
#  'those',
#  'responsible',
#  '—',
#  'from',
#  'the',
#  'highest',
#  'ranked',
#  'to',
#  'the',
#  'lowest',
#  '—',
#  'and',
#  'to',
#  'bring',
#  'them',
#  'to',
#  'justice”',
#  'erdogan',
#  'laid',
#  'out',
#  'a',
#  'timeline',
#  'of',
#  'the',
#  'events',
#  'before',
#  'and',
#  'after',
#  'khashoggi’s',
#  'death',
#  'including',
#  'the',
#  'use',
#  'of',
#  'a',
#  '“body',
#  'double”',
#  'as',
#  'a',
#  'decoy',
#  'three',
#  'people',
#  'flew',
#  'from',
#  'riyadh',
#  'to',
#  'istanbul',
#  'at',
#  'around',
#  '4:30',
#  'pm',
#  'local',
#  'time',
#  'on',
#  'oct',
#  '1',
#  'and',
#  'went',
#  'to',
#  'the',
#  'hotel',
#  'and',
#  'later',
#  'to',
#  'the',
#  'saudi',
#  'consulate',
#  'erdogan',
#  'said',
#  'according',
#  'to',
#  'sky',
#  'news',
#  'another',
#  'team',
#  'went',
#  'from',
#  'the',
#  'consulate',
#  'to',
#  'belgrave',
#  'woods',
#  'and',
#  'yelova',
#  'near',
#  'the',
#  'consulate',
#  'to',
#  'scout',
#  'the',
#  'area',
#  'he',
#  'said',
#  'the',
#  'next',
#  'day',
#  'erdogan',
#  'said',
#  'a',
#  'team',
#  'of',
#  'about',
#  '15',
#  'saudis',
#  'met',
#  'at',
#  'the',
#  'consulate',
#  'between',
#  '9:50',
#  'am',
#  'and',
#  '11',
#  'am',
#  'he',
#  'said',
#  'the',
#  'team',
#  'took',
#  'out',
#  'the',
#  '“hard',
#  'disc”',
#  'from',
#  'the',
#  'consulate’s',
#  'cctv',
#  'and',
#  'called',
#  'khashoggi',
#  'to',
#  'let',
#  'him',
#  'know',
#  'he',
#  'had',
#  'a',
#  'meeting',
#  'at',
#  'the',
#  'consulate',
#  'later',
#  'in',
#  'the',
#  'day',
#  'all',
#  'evidence',
#  'gathered',
#  'shows',
#  'that',
#  'jamal',
#  'khashoggi',
#  'was',
#  'the',
#  'victim',
#  'of',
#  'a',
#  'savage',
#  'murder',
#  '—',
#  'turkish',
#  'president',
#  'erdogan',
#  'khashoggi',
#  'arrived',
#  'at',
#  'the',
#  'consulate',
#  'at',
#  'around',
#  '1:08',
#  'pm',
#  'local',
#  'time',
#  'and',
#  'was',
#  'never',
#  'seen',
#  'again',
#  'erdogan',
#  'said',
#  'almost',
#  'five',
#  'hours',
#  'later',
#  'khashoggi’s',
#  'fiancé',
#  'alerted',
#  'authorities',
#  'that',
#  'he',
#  'had',
#  'been',
#  'detained',
#  'or',
#  'worse',
#  'in',
#  'his',
#  'speech',
#  'erdogan',
#  'suggested',
#  'khashoggi',
#  'was',
#  'the',
#  'victim',
#  'of',
#  'a',
#  '“gruesome',
#  'murder”',
#  'and',
#  'said',
#  'there',
#  'could',
#  'be',
#  'no',
#  'coverup',
#  '“i',
#  'do',
#  'not',
#  'doubt',
#  'the',
#  'sincerity',
#  'of',
#  'king',
#  'salman',
#  'that',
#  'being',
#  'said',
#  'independent',
#  'investigation',
#  'needs',
#  'to',
#  'be',
#  'carried',
#  'out',
#  'this',
#  'is',
#  'a',
#  'political',
#  'killing”',
#  'erdogan',
#  'said',
#  'adding',
#  'khashoggi’s',
#  'death',
#  'was',
#  'meticulously',
#  'planned',
#  'erdogan',
#  'also',
#  'noted',
#  'he',
#  'spoke',
#  'with',
#  'president',
#  'trump',
#  'about',
#  'the',
#  'killing',
#  'but',
#  'didn’t',
#  'reveal',
#  'details',
#  'about',
#  'their',
#  'conversation',
#  'trump',
#  'said',
#  'monday',
#  'he',
#  'wasn’t',
#  'satisfied',
#  'with',
#  'the',
#  'explanations',
#  'he’s',
#  'heard',
#  'about',
#  'the',
#  'killing',
#  'of',
#  'khashoggi',
#  'and',
#  'was',
#  'waiting',
#  'for',
#  'reports',
#  'from',
#  'us',
#  'officials',
#  'returning',
#  'from',
#  'the',
#  'region',
#  "“we're",
#  'going',
#  'to',
#  'get',
#  'to',
#  'the',
#  'bottom',
#  'of',
#  'it',
#  'we',
#  'have',
#  'people',
#  'over',
#  'in',
#  'saudi',
#  'arabia',
#  'now',
#  'we',
#  'have',
#  'top',
#  'intelligence',
#  'people',
#  'in',
#  'turkey',
#  "they're",
#  'coming',
#  'back',
#  'either',
#  'tonight',
#  'or',
#  'tomorrow”',
#  'trump',
#  'told',
#  'the',
#  'media',
#  'before',
#  'leaving',
#  'a',
#  'rally',
#  'in',
#  'texas',
#  'fox',
#  'news’',
#  'greg',
#  'palkot',
#  'and',
#  'the',
#  'associated',
#  'press',
#  'contributed',
#  'to',
#  'this',
#  'report']

# %%
def convert_text_to_dtm(txt):
    '''
    This function is used to convert a list of strings into a single row document term matrix
    '''
    d = dict()
    for word in tokenize(txt):
        if word in d:
            d[word][0] += 1
        else:
            d[word] = [1]
    return pd.DataFrame(d)

# %%
def gen_DTM(texts=None):
    '''
    This function takes a list of list of strings and individually converts them into separate document term matrices.
    After they're converted into matrices, they're row-binded and 0s are inserted as missing values.
    '''
    DTM = pd.DataFrame()
    for text in texts:
        entry = convert_text_to_dtm(text)
        DTM = DTM.append(pd.DataFrame(entry),ignore_index=True,sort=True) # Row bind
    
    DTM.fillna(0, inplace=True) # Fill in any missing values with 0s (i.e. when a word is in one text but not another)
    return DTM

# %%
full_DTM = gen_DTM([aj, bbc, bb, cnn, fox])

# %%
# Remove columns from DTM that have entries in stop_words
full_dtm_cols = list(full_DTM.columns)
for i in range(len(full_dtm_cols)):
    if full_dtm_cols[i] in stop_words.values:
        full_DTM = full_DTM.drop([full_dtm_cols[i]], axis=1)

# %%
# Remaining words in the full document term matrix
full_DTM.columns.values
# Out:
# array(['$50bn', "'where", '1', '11', '12', '15', '15member', '18', '1:08',
#        '2', '28', '2r', '4:30', '55mile', '59', '59yearold',
#        '90kilometer', '9:50', 'abdulaziz', 'abdulaziz”', 'absent',
#        'accident', 'accidentally', 'accidentallyerdogan', 'account',
#        'accounts', 'account”', 'accusation', 'accusing', 'acknowledged',
#        'added', 'adding', 'addition', 'address', 'addressing', 'adel',
#        'admitted', 'admitting', 'advance', 'agency', 'ago', 'aides', 'ak',
#        'akp', 'al', 'alerted', 'alibi', 'alive', 'aljubeir', 'allegation',
#        'allegedly', 'allowed', 'ally', 'alqahtani', 'amounted', 'ankara',
#        'ankaraamong', 'announced', 'anonymous', 'answered', 'answering',
#        'answers', 'anticipated', 'appeared', 'appearing', 'applause',
#        'arabia', "arabia's", 'arabian', 'arabia’s', 'arabic', 'arguing',
#        'arrested', 'arrests', 'arrival', 'arrived', 'arrives',
#        'assassination', 'attempt', 'attempts', 'attendees', 'attributed',
#        'audience', 'audio', 'authenticity', 'authorities', 'authority',
#        'avoided', 'aware', 'bbc', "bbc's", 'beard', 'belgrad', 'belgrave',
#        'bin', 'blame', 'blaming', 'body', "body'", 'bombshell', 'borders',
#        'bottom', 'brawlpeople', 'bring', 'broadcast', 'brookings',
#        'brutal', 'building', 'burden', 'business', 'cabinet', 'cafe',
#        'call', 'called', 'camera', 'capital', 'caption', 'carried',
#        'carry', 'carrying', 'caused', 'cctv', 'ceos', 'chaired',
#        'channels', 'chartered', 'chokehold', 'cia', 'city', 'claim',
#        'claims', 'close', 'cnn', 'coincided', 'columnist', 'columnist’s',
#        'coming', 'commission', 'community', 'community”', 'compounded',
#        'comprehensive', 'condemned', 'condemning', 'condolences',
#        'conference', 'confidence', 'confident', 'confirmed',
#        'conflicting', 'connection', 'conscience”', 'considered',
#        'conspicuously', 'consular', 'consulate', "consulate's",
#        'consulate’s', 'contention', 'continue', 'contracts',
#        'contradicting', 'contributed', 'contributor', 'conversation',
#        'cooperation', 'cooperator', 'cooperator”', 'copy', 'copyright',
#        'correspondent', 'countries”', 'country', 'country’s', 'court',
#        'courts', 'cover', 'coverup', 'create', 'crime”', 'crisis',
#        'critic', 'critics', 'crown', 'crude', 'custodian', 'dalay', 'day',
#        'days', 'daytoday', 'death', 'declared', 'decoy', 'deliberately',
#        'delivering', 'demanded', 'demands', 'deny', 'department',
#        'detailed', 'details', 'detained', 'development', 'device',
#        'didn’t', 'died', 'diplomatic', 'direct', 'director',
#        'disappearance', 'disappeared', 'disc”', 'dismissing', 'dispose',
#        'disposed', 'distinction', 'documents', 'dog', 'doha', 'donald',
#        'don’t', 'double”', 'doubt', 'dozens', 'drive', 'drives', 'dying',
#        'efforts', 'embassy', 'employed', 'entering', 'epa', 'erdogan',
#        "erdogan's", 'erodgan', 'event', 'events', 'evidence', 'exclusive',
#        'exhibited', 'exists', 'expect', 'expectations', 'explanation',
#        'explanations', 'explosive', 'expose', 'extradited', 'fake',
#        'family', 'fell', 'fellow', 'ferocious', 'fiancé', 'fifteen',
#        'figure', 'fired', 'fistfight', 'flew', 'flights', 'flourish',
#        'forceful', 'foreign', 'forest', 'forthcoming', 'found',
#        'foundread', 'fox', 'frank', 'friendship', 'fuelling', 'fullblown',
#        'future', 'galip', 'gardner', 'gather', 'gathered', 'gathering',
#        'gina', 'giving', 'glasses', 'global', 'government', 'greg',
#        'growing', 'gruesome', 'hand', 'handful', 'happen', 'happened',
#        'hard', 'hardfaced', 'haspel', 'haul', 'head', 'heard', 'heard”',
#        'held', 'he’s', 'highlighted', 'highly', 'hit', 'hold', 'holy',
#        'host', 'hotel', 'hours', 'house', 'human', 'hurt', 'identity',
#        'image', 'images', 'implied', 'importance', 'incident', 'included',
#        'including', 'independent', 'indicating', "individual's",
#        'individuals', 'information', 'initially', 'inside', 'insisted',
#        'instantly', 'institute', 'institution', 'instruction',
#        'instructions', 'insults', 'intelligence', 'intended', 'intense',
#        'international', 'interrogation', 'interview', 'investigation',
#        'investigators', 'investment', 'investments', 'involved',
#        'involvement', 'istanbul', 'istanbulit', 'it”', 'i’ve', 'jamal',
#        'jared', 'jazeera', 'job', 'journalist', 'justice', 'justice”',
#        'khashoggi', "khashoggi's", 'khashoggi’s', 'killed', 'killing',
#        'killing”', 'king', 'kingdom', "kingdom's", 'kushner', 'laid',
#        'land', 'lawmakers', 'leader', 'leaders', 'leadership', 'leading',
#        'leaked', 'leaving', 'left', 'legislators', 'light', 'listened',
#        'local', 'locations', 'looked', 'lose', 'lowest', 'maintaining',
#        'manner', 'marriage', 'matter', 'mbs', 'means', 'media', 'meet',
#        'meeting', 'megadeals', 'mention', 'mentioning', 'met',
#        'meticulously', 'mike', 'minister', 'missing', 'mission',
#        'mistake', 'mixture', 'mohammed', 'monday', 'mood', 'mosques',
#        'mps', 'muchdiscussed', 'murder', 'murdered', 'murder”', 'naked',
#        'naming', 'nationals', 'news', 'news’', 'nonresident', 'notable',
#        'noted', 'obtain', 'obtained', 'oct', 'october', 'odd', 'offer',
#        'offering', 'official', 'officials', 'openly', 'operation',
#        'operative', 'opportunities', 'optimism', 'organisation', 'outfit',
#        'outlined', 'outrage', 'outskirts', 'overshadowed', 'oxford',
#        'ozhan', 'palkot', 'paperwork', 'parliament', 'partners', 'party',
#        'people', "people's", 'person', 'phone', 'plan', 'planes',
#        'planned', 'planned”', 'playback', 'played', 'pm', 'police',
#        'political', 'pompeo', 'post', 'powerful', 'pragmatism', 'praised',
#        'praising', 'premeditated', 'president', 'press', 'pressure',
#        'prevent', 'prince', "prince's", 'prior', 'probe', 'prominent',
#        'pronounced', 'provide', 'provided', 'publicly', 'pulled',
#        'punished', 'punishment', 'qualifications', 'question',
#        'questioned', 'questioning', 'questions', 'quoted', 'quoting',
#        'rally', 'ranked', 'reasons', 'recep', 'reconnaissance', 'reform',
#        'refusing', 'refuted', 'region', 'rejected', 'rejection',
#        'related', 'remained', 'remains', 'removed', 'report', 'reports',
#        'research', 'resident', 'resisting', 'resounding', 'responsible',
#        'rests', 'result', 'return', 'returned', 'returning', 'reuters',
#        'reveal', 'revealed', 'reveals', 'revelations', 'review', 'rights',
#        'riyadh', 'roadmap', 'rogue', 'role', 'rolled', 'royals', 'rug',
#        'ruler', 'ruling', 'sacked', 'salah', 'salman', "salman's",
#        'satisfied', 'satisfy', 'saturday', 'saud', 'saudi', 'saudis',
#        'savage', 'savagery', 'scandal', 'scholar', 'scope', 'scout',
#        'scouted', 'scrum', 'searched', 'sebastian', 'secretary',
#        'security', 'seeking', 'selfapprobation', 'separate', 'september',
#        'set', 'short', 'signed', 'significance', 'silent', 'sincerity',
#        'situation', 'situation”', 'sky', 'skype', 'solve', 'son',
#        'soninlaw', 'sort', 'soundly', 'sour', 'sources', 'south',
#        'speaking', 'specifically', 'speech', 'speechthe', 'spoke',
#        'squad', 'staff', 'stand', 'start', 'started', 'statement', 'stay',
#        'step', 'steps', 'stopped', 'story', 'stressed', 'strong',
#        'strongly', 'subject', 'suggested', 'sunday', 'support',
#        'surveillance', 'suspects', 'system', 'taha', 'taking', 'tape',
#        'tayyip', 'team', 'teams', 'term', 'terrible', 'texas', 'that’s',
#        'there”', 'time', 'timeline', 'told', 'tomorrow”', 'tonight',
#        'top', 'topic', 'traded', 'tragedy', 'trailed', 'transparent”',
#        'travelled', 'tremendous', 'trial', 'trials', 'trump', "trump's",
#        'trump’s', 'truth', 'tuesday', "tuesday's", 'turkey', "turkey's",
#        'turkey”', 'turkish', 'tv', 'uncomfortable', 'underlined',
#        'university', 'unnamed', 'unreality', 'unsatisfied', 'unsupported',
#        'urged', 'urgency', 'usher', 'victim', 'video', 'vision',
#        'visited', 'visiting', 'vote', 'waiting', 'wake', 'walked',
#        'washington', 'wasn’t', 'watch', 'watching', 'wearing', 'wedding',
#        'week', 'weeks', 'we’re', 'white', 'widely', 'withheld', 'woods',
#        'world', 'worse', 'writer', 'yalova', 'yelova', '£385bn', '—',
#        '“all', '“body', '“fistfight”', '“fully', '“gruesome', '“hard',
#        '“i', '“it', '“local', '“may', '“other', '“partner', '“putting',
#        '“saudi', '“the', '“to', '“we', "“we're", '“why'], dtype=object)

# %%
# Create numpy arrays for each of the rows in the dictionary term matrix to determine similarity

# Al Jazeera
aj_row = full_DTM.iloc[0].values

# BBC row
bbc_row = full_DTM.iloc[1].values

# Breitbart row
bb_row = full_DTM.iloc[2].values

# CNN row
cnn_row = full_DTM.iloc[3].values

# Fox row
fox_row = full_DTM.iloc[4].values

# %%
# Create cosine function
def cosine(a,b):
    '''
    This function returns the cosine of the angle of two vectors, in this case numpy arrays from the DTM.
    This function will return a value of cosine for quadrant I, which will be somewhere between 0 and 1.
    The closer the value is to 1, the more similar the words will be.
    '''
    cos = np.dot(a,b)/(np.sqrt(np.dot(a,a)) * np.sqrt(np.dot(b,b)))
    return cos

# %%
# Test similarity between Al Jazeera and BBC
cosine(aj_row, bbc_row).round(3)
# Out:
# 0.678

# %%
# Test similarity between Al Jazeera and Breitbart
cosine(aj_row, bb_row).round(3)
# Out:
# 0.555

# %%
# Test similarity between Al Jazeera and CNN
cosine(aj_row, cnn_row).round(3)
# Out:
# 0.532

# %%
# Test similarity between Al Jazeera and Fox
cosine(aj_row, fox_row).round(3)
# Out:
# 0.66

# %% [markdown]
# Based on these numbers, the article from Al Jazeera was most similar to the article from the BBC. This could make sense as Al Jazeera and BBC are both based outside the United States while the others are not.
#
# Now, let's test the similarity between the BBC articles and the articles from the United States based sources to see if this holds up.

# %%
# Test similarity between BBC and Breitbart
cosine(bbc_row, bb_row).round(3)
# Out:
# 0.564

# %%
# Test similarity between BBC and CNN
cosine(bbc_row, cnn_row).round(3)
# Out:
# 0.504

# %%
# Test similarity between BBC and Fox
cosine(bbc_row, fox_row).round(3)
# Out:
# 0.606

# %% [markdown]
# Seeing as these numbers are all closer to 0 than 0.678, this hypothesis seems to hold up. Now, we can see if this is also true for the United States based sources.

# %%
# Test similarity between Breitbart and CNN
cosine(bb_row, cnn_row).round(3)
# Out:
# 0.353

# %%
# Test similarity between Breitbart and Fox
cosine(bb_row, fox_row).round(3)
# Out:
# 0.519

# %%
# Test similarity between CNN and Fox
cosine(cnn_row, fox_row).round(3)
# Out:
# 0.514

# %% [markdown]
# Based on these numbers, it seems as though the United States based sources are actually more similar to the articles from Al Jazeera and BBC than they are to other articles from United States based sources! So, we can not say that the differences between all of them occur due to United States centric perspective in the articles.
